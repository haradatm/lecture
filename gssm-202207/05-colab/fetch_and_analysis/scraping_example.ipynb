# %%
import math, random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
np.set_printoptions(precision=8)

seed = 42
random.seed(seed)
np.random.seed(seed)

# %matplotlib inline

# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
target_url = "http://travel.rakuten.co.jp/yado/kanagawa/hakone.html"

# %%
text_list = []

soup_plans = BeautifulSoup(requests.get(target_url).text, 'html.parser')
num_plan_pages = int(soup_plans.select('.pagingTitle')[0].select('em')[0].text)

for i in range(int(num_plan_pages / 30) + 1):
    url = target_url.replace('travel.rakuten.co.jp', 'search.travel.rakuten.co.jp/ds')
    url = re.sub(r'.html', ('-p%s' % (i+1)), url)
    print(f'Number of plan pages: {i+1:d}/{num_plan_pages:d} --> {url}')
    soup_plan_page = BeautifulSoup(requests.get(url).text, 'html.parser')

    for tags in soup_plan_page.select('.htlList .info'):
        tag = tags.select('h1 a')
        url = tag[0].get('href')
        url = re.sub(r'/[0-9]+.html.*$', '/review.html', url)
        soup_reviews = BeautifulSoup(requests.get(url).text, 'html.parser')
        num_review_pages = int(soup_reviews.select('.pagingTitle')[0].select('em')[0].text)

        for j in range(int(num_review_pages / 20) + 1):
            url = soup_reviews.select('.pagingNumber a')[0].get('href')
            url = re.sub(r'f_next=.*', 'f_next=', url)
            url = '{:}{:}'.format(url, (j * 20))
            print(f'Number of review pages: {j+1:d}/{num_review_pages:d} --> {url}')
            soup_review_page = BeautifulSoup(requests.get(url).text, 'html.parser')            

            for tags in soup_review_page.select('.commentBox'):
                tag = tags.select('.commentTitle a')[0]
                url = tag.get('href')
                soup_comments = BeautifulSoup(requests.get(url).text, 'html.parser')
                comment = soup_comments.select('.commentBox')[0]
                text = comment.select('.commentSentence')[0].get_text(strip=True)
                text = re.sub('\r\n', ' ', text)
                text = re.sub('\n',   ' ', text)
                text = re.sub('\t',   ' ', text)
                text_list.append(text)

            # 今回は練習用として1ページ目のレビューだけで中断する
            break

        # 今回は練習用として1プランだけで中断する
        break

    # 今回は練習用として1ページ目のプランだけで中断する
    break
# Out:
# Number of plan pages: 1/313 --> http://search.travel.rakuten.co.jp/ds/yado/kanagawa/hakone-p1
# Number of review pages: 1/191 --> https://review.travel.rakuten.co.jp/hotel/voice/146841/?f_time=&f_keyword=&f_age=0&f_sex=0&f_mem1=0&f_mem2=0&f_mem3=0&f_mem4=0&f_mem5=0&f_teikei=&f_version=2&f_static=1&f_point=0&f_sort=0&f_next=0

# %%
text_df = pd.DataFrame(text_list)
text_df.columns = ['text']
print(text_df.shape)
display(text_df)
# Out:
# (20, 1)
#                                                  text
# 0   お料理が全部美味しかったです！お部屋も良かったですし、露天風呂も気持ち良かったです。また行こ...
# 1   失敗でした。この宿は県民割に参加していないので、楽天から予約しました。3000円しか補助され...
# 2                                      部屋付き露天風呂が良かった。
# 3   6月22日結婚60周年記念に夫婦で宿泊させて頂きました。洋室の部屋も露天風呂も広々として、更...
# 4   結婚式翌日に一泊宿泊しました。結構山道を登った先にあるので、場所は少し分かりづらいです。到着...
# 5   皆さんの口コミの通り、露天風呂は広かったです。　ただ、サイトに載っている写真と露天風呂の形状...
# 6   カップルで宿泊しましたが専用露天風呂が思っていた以上に広々としていて最高でした！畳に一部シミ...
# 7   妊娠の為事前にお伝えし、お料理や飲み物を色々変更して頂き本当にありがとうございました。お料理...
# 8   6/11（土）家内と二人で利用させていただきました。11年間の単身赴任期間に子達の世話も含め...
# 9   母娘旅行で宿泊させて頂きました。事前に妊婦と伝えていた為お料理や飲み物など変更してくださって...
# 10  一泊二日でお世話になりました。スタッフの方は皆さんとても親切で感じが良かったです。お食事もと...
# 11  旅館のPRの通り大変良かった。欠点は、Wi-fiが各部屋ではつかえず、ホールに出かけないとだ...
# 12  お部屋のお風呂はとても良かったですですが　外を歩いている人と目があったりしたましたとても困り...
# 13  若いスタッフの方たちの明るい笑顔、丁寧な言葉遣い、お心遣い、お客様に対しての温かいおもてなし...
# 14  箱根のいろんな宿に泊まったことがありますが、ここは中の中くらいです。評価の通り食事は食器にも...
# 15  初めて専用露天風呂つきの旅館を利用したので比較が出来ませんがとても良かったです。専用露天風呂...
# 16  早目の梅雨の走りと言われていましたが、ちょうどお天気に恵まれました。口コミも大変よく、お部屋...
# 17  サービス面がよかったです！お部屋の大きさもよかったです。露天風呂は解放感があって、一番おすす...
# 18  私は、夫婦で年間8回前後の個人旅行を楽しんでおります。今回 お世話になった宿は残念ながら不満...
# 19  ホテルまでの道のりが坂がありキツかったのですが、お部屋、部屋付き露天風呂、食事には大変満足で...

# %% [markdown]
# ### Ginza を使ってみる

# %%
# !pip install ja-ginza > /dev/null 2>&1

# %%
import spacy
import ginza

# ja-ginza モデルのロード
nlp = spacy.load('ja_ginza')

# 単語連結モードを選択
ginza.set_split_mode(nlp, "C")

for p in nlp.pipeline:
    print(p)
# Out:
# ('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x7f312f520ad0>)
# ('parser', <spacy.pipeline.dep_parser.DependencyParser object at 0x7f313c8eeb50>)
# ('ner', <spacy.pipeline.ner.EntityRecognizer object at 0x7f313c8ee850>)
# ('morphologizer', <spacy.pipeline.morphologizer.Morphologizer object at 0x7f312f522360>)
# ('compound_splitter', <ginza.compound_splitter.CompoundSplitter object at 0x7f312ced2990>)
# ('bunsetu_recognizer', <ginza.bunsetu_recognizer.BunsetuRecognizer object at 0x7f312cf39890>)

# %% [markdown]
# ### 文の解析 (形態素解析)

# %%
# ja-ginza モデルのロード
nlp = spacy.load('ja_ginza')

result_list = []

# 文の解析
for i, text in enumerate(text_list):
    doc = nlp(text)
    for j, sent in enumerate(doc.sents):
      for token in sent:
        result_list = result_list + [[i, j, token.i, token.text, token.lemma_, token.pos_, token.tag_]]
    j = 0

result_df = pd.DataFrame(result_list, columns = ['doc_no', 'sent_no', 'token_no', 'text', 'lemma', 'pos', 'tag'])      
result_df
# Out:
#       doc_no  sent_no  token_no   text lemma    pos           tag
# 0          0        0         0      お     お   NOUN           接頭辞
# 1          0        0         1     料理    料理   NOUN  名詞-普通名詞-サ変可能
# 2          0        0         2      が     が    ADP        助詞-格助詞
# 3          0        0         3     全部    全部    ADV  名詞-普通名詞-副詞可能
# 4          0        0         4  美味しかっ  美味しい    ADJ        形容詞-一般
# ...      ...      ...       ...    ...   ...    ...           ...
# 2065      19        4       101      て     て  SCONJ       助詞-接続助詞
# 2066      19        4       102      み    みる   VERB      動詞-非自立可能
# 2067      19        4       103     たい    たい    AUX           助動詞
# 2068      19        4       104     です    です    AUX           助動詞
# 2069      19        4       105      。     。  PUNCT       補助記号-句点
#
# [2070 rows x 7 columns]

# %% [markdown]
# ### 係り受け解析

# %%
from spacy import displacy

# 文の解析
for i, text in enumerate(text_list):
    doc = nlp(text)
    for j, sent in enumerate(doc.sents):
        print(f"文: {sent}")

        # 係り受け解析
        displacy.render(sent, style="dep", options={"compact":True}, jupyter=True)

        # 今回は練習用として1文だけで中断する
        break

    # 今回は練習用として1件だけで中断する
    break
# Out:
# 原文: お料理が全部美味しかったです！
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="ba25fbfd4f1547fbaa11802c75248a43-0" class="displacy" width="1100" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">お</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">料理</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">が</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">全部</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">美味しかっ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">た</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">です！</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-1" stroke-width="2px" d="M212,227.0 212,152.0 650.0,152.0 650.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-2" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M344.0,229.0 L348.0,221.0 340.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-3" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-4" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,229.0 L798.0,221.0 790.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ba25fbfd4f1547fbaa11802c75248a43-0-5" stroke-width="2px" d="M662,227.0 662,177.0 947.0,177.0 947.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ba25fbfd4f1547fbaa11802c75248a43-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M947.0,229.0 L951.0,221.0 943.0,221.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### 固有表現抽出

# %%
# 警告を抑止する
import warnings
warnings.simplefilter('ignore', UserWarning)

# 文の解析
for i, text in enumerate(text_list):
    doc = nlp(text)

    # 固有表現抽出
    displacy.render(doc, style="ent", jupyter=True)

    # 今回は練習用として5件だけで中断する
    if i >= 4:
      break

warnings.resetwarnings()
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">お料理が全部美味しかったです！お部屋も良かったですし、露天風呂も気持ち良かったです。また行こうと思います。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">失敗でした。この宿は
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     県民割
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Percent</span>
# </mark>
# に参加していないので、楽天から予約しました。
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3000円
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Money</span>
# </mark>
# しか補助されず、
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5%引き
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Percent</span>
# </mark>
# も使えませんでした。
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ク－ポン券
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Dish</span>
# </mark>
# は、
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     チェック・イン
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Person</span>
# </mark>
# の
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3時以降
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# しか発行してもらえず、食事の時の飲み物代にも使えませんでした。今迄何回も県民割を使ってきましたが、いい勉強になりました。チェック・イン時には、フロントで荷物を持ったまま立って書類を書かせたり、他にも
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     首
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# を傾げる事が多く不愉快でした。お風呂は、何度も露付きを利用した中で
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     一番
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Rank</span>
# </mark>
# ですが、外から丸見えなので、おどおどしながら入るのは初めてでした。又行きたいとは思いませんでした。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">部屋付き露天風呂が良かった。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6月22日
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     結婚60周年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
# 記念に夫婦で宿泊させて頂きました。洋室の部屋も露天風呂も広々として、更に湯舟に何度も身を浸し乍ら眼前に広がる
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新緑の
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Archaeological_Place_Other</span>
# </mark>
# もみじにうっとり・・・・何と素晴らしい
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     一時
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# だったことでしょう！又、個室で
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1品
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Product</span>
# </mark>
# ずつサーブされた
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     夕食
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# の味もとても美味しく、この宿に決めてよかったと
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     二人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# で話合いました。宿の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     スタッフ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# の皆さんの応対も明るく親切で、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     女性スタッフ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     制服
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Clothing</span>
# </mark>
# 、客用の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     浴衣
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Clothing</span>
# </mark>
# も素敵でした。最後に一言、翌日の朝食は、凝りすぎた少量多種でなく、今少し数を絞った方が、料理を作って下さる方々の折角の工夫・苦労が生かされるのではないかと失礼ながら愚考します。今回は大変有難う御座いました。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     結婚式
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Occasion_Other</span>
# </mark>
# 翌日に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     一泊
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Day</span>
# </mark>
# 宿泊しました。結構山道を登った先にあるので、場所は少し分かりづらいです。到着が遅かったので
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     駐車場
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Facility_Part</span>
# </mark>
# が奥になってしまい、かなり停めづらかったです。館内はこじんまりとした感じ。
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     スタッフさん
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# の対応は丁寧で気持ちよかったです。食事は月替りメニューらしく、季節感のあるお食事でした。少食ですが頑張れば食べ切れる量だったのと、何を食べてもおいしくて完食しました。部屋のすぐ外に露天風呂があり、外は林が広がっているので視線を気にせず入れました。両隣も
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ご宿泊
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Weapon</span>
# </mark>
# の方がいらしたみたいですが、中でも外でも声は聞こえず、静かに過ごせました。タオルが
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ひとり
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ２枚
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Product</span>
# </mark>
# ずつ用意してもらえてるのが良かったです。館内には売店はないので、お土産とかは別で探す必要があります。自販機はありました。内湯は利用しませんでした。コンビニも近くにはないので、持ち込む場合は早めに買ったほうがいいです。アメニティの歯ブラシがめちゃくちゃ硬いので、可能なら持ち込んだほうがいいです。全体的には満足できました。露天風呂とお食事とスタッフさんの対応が最高です。また行きたいと思います。</div></span>
